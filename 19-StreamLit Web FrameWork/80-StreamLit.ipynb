# %%
! pip install streamlit
# Out:
# Requirement already satisfied: streamlit in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.56.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (2.4.2)
# Requirement already satisfied: packaging>=20 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<4,>=1.4.0 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (3.0.1)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (7.34.0)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in C:\Users\gp298\AppData\Roaming\Python\Python311\site-packages (from streamlit) (6.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\gp298\AppData\Roaming\Python\Python311\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.19.0)
# Requirement already satisfied: colorama in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in C:\Users\gp298\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)

# %%
## Use Pyhton 3.11.9 ....

# %%
import streamlit as st
import pandas as pd
import numpy as np

# %%
## Title of the application
st.title("Hello StreamLit")

## Display a simple text
st.write("This is my first StreamLit application")
# Out:
# 2026-04-17 18:48:26.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:26.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:26.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:26.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:26.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:26.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
## Create a simple dataframe
df = pd.DataFrame({
    "first column": [1, 2, 3, 4],
    "second column": [10, 20, 30, 40]
})

## Display the dataframe as a table
st.write("This is a dataframe:")
st.write(df)
# Out:
# 2026-04-17 18:48:26.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:26.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:26.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:26.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:26.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:26.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
## Create a line chart from the dataframe
chat_data = pd.DataFrame(
    np.random.randn(20, 3),
    columns=["a", "b", "c"]
)
st.line_chart(chat_data)
# Out:
# 2026-04-17 18:48:27.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:27.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-17 18:48:27.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
